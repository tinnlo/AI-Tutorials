# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product ">
# </a>

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork/image/IDSN-logo.png" width="200" alt="cognitiveclass.ai logo">

# %% [markdown]
# <h1><h1>Pre-trained-Models with PyTorch </h1>

# %% [markdown]
# In this lab, you will use pre-trained models to classify between the negative and positive samples; you will be provided with the dataset object. The particular pre-trained model will be resnet18; you will have three questions:
# <ul>
# <li>change the output layer</li>
# <li> train the model</li>
# <li>  identify  several  misclassified samples</li>
#  </ul>
# You will take several screenshots of your work and share your notebook.

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
#
# <ul>
#     <li><a href="#download_data"> Download Data</a></li>
#     <li><a href="#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="#data_class"> Dataset Class</a></li>
#     <li><a href="#Question_1">Question 1</a></li>
#     <li><a href="#Question_2">Question 2</a></li>
#     <li><a href="#Question_3">Question 3</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>120 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# Download the dataset and unzip the files in your data directory, unlike the other labs, all the data will be deleted after you close  the lab, this may take some time:

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Out:
# --2024-07-10 16:46:28--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2598656062 (2.4G) [application/zip]
# Saving to: ‘Positive_tensors.zip’
#
# Positive_tensors.zi 100%[===================>]   2.42G  1.66MB/s    in 13m 47s
#
# 2024-07-10 17:00:16 (3.00 MB/s) - ‘Positive_tensors.zip’ saved [2598656062/2598656062]

# %%
# !unzip -q Positive_tensors.zip

# %%
! wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# !unzip -q Negative_tensors.zip
# Out:
# --2024-07-10 17:01:48--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2111408108 (2.0G) [application/zip]
# Saving to: ‘Negative_tensors.zip’
#
# Negative_tensors.zi 100%[===================>]   1.97G  1.91MB/s    in 14m 12s
#
# 2024-07-10 17:16:01 (2.36 MB/s) - ‘Negative_tensors.zip’ saved [2111408108/2111408108]

# %% [markdown]
# We will install torchvision:

# %%
# !pip install torchvision

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab. The <code>torch.manual_seed()</code> is for forcing the random function to give the same number every time we try to recompile it.

# %%
# These are the libraries will be used for this lab.
import torchvision.models as models
from PIL import Image
import pandas
from torchvision import transforms
import torch.nn as nn
import time
import torch 
import matplotlib.pylab as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader
import h5py
import os
import glob
torch.manual_seed(0)

# %%
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt
from PIL import Image
import pandas as pd
import os

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="data_class">Dataset Class</h2>

# %% [markdown]
#  This dataset class is essentially the same dataset you build in the previous section, but to speed things up, we are going to use tensors instead of jpeg images. Therefor for each iteration, you will skip the reshape step, conversion step to tensors and normalization step.

# %%
# Create your own dataset object

class Dataset(Dataset):

    # Constructor
    def __init__(self,transform=None,train=True):
        directory="./"
        positive="Positive_tensors"
        negative='Negative_tensors'

        positive_file_path=os.path.join(directory,positive)
        negative_file_path=os.path.join(directory,negative)
        positive_files=[os.path.join(positive_file_path,file) for file in os.listdir(positive_file_path) if file.endswith(".pt")]
        negative_files=[os.path.join(negative_file_path,file) for file in os.listdir(negative_file_path) if file.endswith(".pt")]
        number_of_samples=len(positive_files)+len(negative_files)
        self.all_files=[None]*number_of_samples
        self.all_files[::2]=positive_files
        self.all_files[1::2]=negative_files 
        # The transform is goint to be used on image
        self.transform = transform
        #torch.LongTensor
        self.Y=torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2]=1
        self.Y[1::2]=0
        
        if train:
            self.all_files=self.all_files[0:30000]
            self.Y=self.Y[0:30000]
            self.len=len(self.all_files)
        else:
            self.all_files=self.all_files[30000:]
            self.Y=self.Y[30000:]
            self.len=len(self.all_files)     
       
    # Get the length
    def __len__(self):
        return self.len
    
    # Getter
    def __getitem__(self, idx):
               
        image=torch.load(self.all_files[idx])
        y=self.Y[idx]
                  
        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)

        return image, y
    
print("done")
# Out:
# done

# %% [markdown]
# We create two dataset objects, one for the training data and one for the validation data.

# %%
train_dataset = Dataset(train=True)
validation_dataset = Dataset(train=False)
print("done")
# Out:
# done

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>

# %% [markdown]
# <b>Prepare a pre-trained resnet18 model :</b>

# %% [markdown]
# <b>Step 1</b>: Load the pre-trained model <code>resnet18</code> Set the parameter <code>pretrained</code> to true:

# %%
# Step 1: Load the pre-trained model resnet18

# Type your code here
model = models.resnet18(pretrained = True)
# Out:
# /Users/lxt/anaconda3/envs/mldl/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/lxt/anaconda3/envs/mldl/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /Users/lxt/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:15<00:00, 3.00MB/s]

# %% [markdown]
# <b>Step 2</b>: Set the attribute <code>requires_grad</code> to <code>False</code>. As a result, the parameters will not be affected by training.

# %%
# Step 2: Set the parameter cannot be trained for the pre-trained model


# Type your code here
for param in model.parameters():
    param.requires_grad = False

# %% [markdown]
# <code>resnet18</code> is used to classify 1000 different objects; as a result, the last layer has 1000 outputs.  The 512 inputs come from the fact that the previously hidden layer has 512 outputs.

# %% [markdown]
# <b>Step 3</b>: Replace the output layer <code>model.fc</code> of the neural network with a <code>nn.Linear</code> object, to classify 2 different classes. For the parameters <code>in_features </code> remember the last hidden layer has 512 neurons.

# %%
num_features = model.fc.in_features     #extract fc layers features
model.fc = nn.Linear(num_features, 2)   #(num_of_class == 2)

# %% [markdown]
# Print out the model in order to show whether you get the correct answer.<br> <b>(Your peer reviewer is going to mark based on what you print here.)</b>

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# <h2 id="Question_2">Question 2: Train the Model</h2>

# %% [markdown]
# In this question you will train your, model:

# %% [markdown]
# <b>Step 1</b>: Create a cross entropy criterion function

# %%
# Step 1: Create the loss function

# Type your code here
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# <b>Step 2</b>: Create a training loader and validation loader object, the batch size should have 100 samples each.

# %%
train_loader = torch.utils.data.DataLoader(dataset = train_dataset, batch_size = 100)
validation_loader = torch.utils.data.DataLoader(dataset= validation_dataset, batch_size = 100)

# %% [markdown]
# <b>Step 3</b>: Use the following optimizer to minimize the loss

# %%
optimizer = torch.optim.Adam([parameters  for parameters in model.parameters() if parameters.requires_grad],lr=0.001)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# **Complete the following code to calculate  the accuracy on the validation data for one epoch; this should take about 45 minutes. Make sure you calculate the accuracy on the validation data.**

# %%
n_epochs=1
loss_list=[]
accuracy_list=[]
correct=0
N_test=len(validation_dataset)
N_train=len(train_dataset)
start_time = time.time()
#n_epochs

Loss=0
start_time = time.time()
for epoch in range(n_epochs):
    for i, (x, y) in enumerate(train_loader):
        
        train_start_time = time.time()
        
        model.train()
        
        #clear gradient 
        optimizer.zero_grad()
        #make a prediction 
        z=model(x)   
        # calculate loss 
        loss=criterion(z,y)
        # calculate gradients of parameters 
        loss.backward()
        # update parameters 
        optimizer.step()
        loss_list.append(loss.data)
        
        print('Train iteration' , i+1, 'completed after ', time.time()-train_start_time, 'seconds')
        
    correct=0
    for i, (x_test, y_test) in enumerate(validation_loader):
        val_start_time = time.time()
        
        # set model to eval 
        model.eval()
        #make a prediction 
        z=model(x_test)
        #find max 
        _,yhat=torch.max(z.data,1)
        
        #Calculate misclassified  samples in mini-batch 
        #hint +=(yhat==y_test).sum().item()
        correct+=(yhat==y_test).sum().item()
   
        print('Validation iteration' , i+1, 'completed after ', time.time()-val_start_time, 'seconds')
    
    accuracy=correct/N_test
    accuracy_list.append(accuracy)

    print('Epoch' , i+1, 'completed after ', time.time()-start_time, 'seconds')
# Out:
# Train iteration 1 completed after  2.6042659282684326 seconds
# Train iteration 2 completed after  2.6274538040161133 seconds
# Train iteration 3 completed after  2.637911081314087 seconds
# Train iteration 4 completed after  2.6488630771636963 seconds
# Train iteration 5 completed after  2.522736072540283 seconds
# Train iteration 6 completed after  2.7243127822875977 seconds
# Train iteration 7 completed after  2.350584030151367 seconds
# Train iteration 8 completed after  2.4361348152160645 seconds
# Train iteration 9 completed after  2.6958882808685303 seconds
# Train iteration 10 completed after  2.580518960952759 seconds
# Train iteration 11 completed after  2.7687618732452393 seconds
# Train iteration 12 completed after  2.7223598957061768 seconds
# Train iteration 13 completed after  2.3331332206726074 seconds
# Train iteration 14 completed after  2.366338014602661 seconds
# Train iteration 15 completed after  2.3327250480651855 seconds
# Train iteration 16 completed after  2.5992701053619385 seconds
# Train iteration 17 completed after  2.6702089309692383 seconds
# Train iteration 18 completed after  2.4930002689361572 seconds
# Train iteration 19 completed after  2.5609819889068604 seconds
# Train iteration 20 completed after  2.509622097015381 seconds
# Train iteration 21 completed after  2.5568649768829346 seconds
# Train iteration 22 completed after  2.4583661556243896 seconds
# Train iteration 23 completed after  2.3135507106781006 seconds
# Train iteration 24 completed after  2.3329479694366455 seconds
# Train iteration 25 completed after  2.307323932647705 seconds
# Train iteration 26 completed after  2.3266680240631104 seconds
# Train iteration 27 completed after  2.288133144378662 seconds
# Train iteration 28 completed after  2.2884838581085205 seconds
# Train iteration 29 completed after  2.2827749252319336 seconds
# Train iteration 30 completed after  2.2802610397338867 seconds
# Train iteration 31 completed after  2.263166904449463 seconds
# Train iteration 32 completed after  2.3008458614349365 seconds
# Train iteration 33 completed after  2.9008209705352783 seconds
# Train iteration 34 completed after  3.0308408737182617 seconds
# Train iteration 35 completed after  3.103318929672241 seconds
# Train iteration 36 completed after  3.2077689170837402 seconds
# Train iteration 37 completed after  2.7507450580596924 seconds
# Train iteration 38 completed after  2.5125718116760254 seconds
# Train iteration 39 completed after  2.414868116378784 seconds
# Train iteration 40 completed after  2.3119618892669678 seconds
# Train iteration 41 completed after  2.2801008224487305 seconds
# Train iteration 42 completed after  2.2641239166259766 seconds
# Train iteration 43 completed after  2.492197275161743 seconds
# Train iteration 44 completed after  2.567678928375244 seconds
# Train iteration 45 completed after  2.7852542400360107 seconds
# Train iteration 46 completed after  2.428070068359375 seconds
# Train iteration 47 completed after  2.4345881938934326 seconds
# Train iteration 48 completed after  2.395407199859619 seconds
# Train iteration 49 completed after  2.3046371936798096 seconds
# Train iteration 50 completed after  2.259364128112793 seconds
# Train iteration 51 completed after  2.28096604347229 seconds
# Train iteration 52 completed after  2.274667978286743 seconds
# Train iteration 53 completed after  2.2881977558135986 seconds
# Train iteration 54 completed after  2.4744021892547607 seconds
# Train iteration 55 completed after  2.611766815185547 seconds
# Train iteration 56 completed after  2.711970090866089 seconds
# Train iteration 57 completed after  2.69978404045105 seconds
# Train iteration 58 completed after  2.755866765975952 seconds
# Train iteration 59 completed after  2.856987953186035 seconds
# Train iteration 60 completed after  2.892526149749756 seconds
# Train iteration 61 completed after  3.077637195587158 seconds
# Train iteration 62 completed after  3.2846410274505615 seconds
# Train iteration 63 completed after  2.801567316055298 seconds
# Train iteration 64 completed after  2.6916279792785645 seconds
# Train iteration 65 completed after  2.4569919109344482 seconds
# Train iteration 66 completed after  2.3397490978240967 seconds
# Train iteration 67 completed after  2.2993669509887695 seconds
# Train iteration 68 completed after  2.254951000213623 seconds
# Train iteration 69 completed after  2.2482223510742188 seconds
# Train iteration 70 completed after  2.2539591789245605 seconds
# Train iteration 71 completed after  2.2387521266937256 seconds
# Train iteration 72 completed after  2.2397351264953613 seconds
# Train iteration 73 completed after  2.2910518646240234 seconds
# Train iteration 74 completed after  2.2493062019348145 seconds
# Train iteration 75 completed after  2.242690086364746 seconds
# Train iteration 76 completed after  2.6438710689544678 seconds
# Train iteration 77 completed after  2.3212223052978516 seconds
# Train iteration 78 completed after  2.2994601726531982 seconds
# Train iteration 79 completed after  2.246734857559204 seconds
# Train iteration 80 completed after  2.2620952129364014 seconds
# Train iteration 81 completed after  2.2740349769592285 seconds
# Train iteration 82 completed after  2.328730821609497 seconds
# Train iteration 83 completed after  2.3413939476013184 seconds
# Train iteration 84 completed after  2.287968873977661 seconds
# Train iteration 85 completed after  2.3371572494506836 seconds
# Train iteration 86 completed after  2.331550121307373 seconds
# Train iteration 87 completed after  2.3870749473571777 seconds
# Train iteration 88 completed after  2.4530749320983887 seconds
# Train iteration 89 completed after  2.254570960998535 seconds
# Train iteration 90 completed after  2.2673797607421875 seconds
# Train iteration 91 completed after  2.2764880657196045 seconds
# Train iteration 92 completed after  2.280880928039551 seconds
# Train iteration 93 completed after  2.2944939136505127 seconds
# Train iteration 94 completed after  2.3003299236297607 seconds
# Train iteration 95 completed after  2.2874109745025635 seconds
# Train iteration 96 completed after  2.2720768451690674 seconds
# Train iteration 97 completed after  2.240004777908325 seconds
# Train iteration 98 completed after  2.313764810562134 seconds
# Train iteration 99 completed after  2.9266180992126465 seconds
# Train iteration 100 completed after  2.6085422039031982 seconds
# Train iteration 101 completed after  2.4532461166381836 seconds
# Train iteration 102 completed after  2.3082549571990967 seconds
# Train iteration 103 completed after  2.3437228202819824 seconds
# Train iteration 104 completed after  2.2606210708618164 seconds
# Train iteration 105 completed after  2.5040230751037598 seconds
# Train iteration 106 completed after  2.4705588817596436 seconds
# Train iteration 107 completed after  2.4224371910095215 seconds
# Train iteration 108 completed after  2.436167001724243 seconds
# Train iteration 109 completed after  2.4814422130584717 seconds
# Train iteration 110 completed after  2.567718982696533 seconds
# Train iteration 111 completed after  2.4221839904785156 seconds
# Train iteration 112 completed after  2.3916079998016357 seconds
# Train iteration 113 completed after  2.513432025909424 seconds
# Train iteration 114 completed after  2.555462121963501 seconds
# Train iteration 115 completed after  2.750844955444336 seconds
# Train iteration 116 completed after  2.3243520259857178 seconds
# Train iteration 117 completed after  2.3868658542633057 seconds
# Train iteration 118 completed after  2.4075520038604736 seconds
# Train iteration 119 completed after  2.7381298542022705 seconds
# Train iteration 120 completed after  2.6556107997894287 seconds
# Train iteration 121 completed after  3.1380040645599365 seconds
# Train iteration 122 completed after  2.956731081008911 seconds
# Train iteration 123 completed after  2.6232922077178955 seconds
# Train iteration 124 completed after  2.889791965484619 seconds
# Train iteration 125 completed after  2.399907112121582 seconds
# Train iteration 126 completed after  2.458026885986328 seconds
# Train iteration 127 completed after  2.3099987506866455 seconds
# Train iteration 128 completed after  2.2638823986053467 seconds
# Train iteration 129 completed after  2.648930072784424 seconds
# Train iteration 130 completed after  2.3151941299438477 seconds
# Train iteration 131 completed after  2.450054883956909 seconds
# Train iteration 132 completed after  2.277475118637085 seconds
# Train iteration 133 completed after  2.318612813949585 seconds
# Train iteration 134 completed after  2.27419376373291 seconds
# Train iteration 135 completed after  2.375765800476074 seconds
# Train iteration 136 completed after  2.2956528663635254 seconds
# Train iteration 137 completed after  2.210634231567383 seconds
# Train iteration 138 completed after  2.3383750915527344 seconds
# Train iteration 139 completed after  2.502923011779785 seconds
# Train iteration 140 completed after  2.393062114715576 seconds
# Train iteration 141 completed after  2.5888540744781494 seconds
# Train iteration 142 completed after  2.386378049850464 seconds
# Train iteration 143 completed after  2.575639009475708 seconds
# Train iteration 144 completed after  2.706285238265991 seconds
# Train iteration 145 completed after  2.3986470699310303 seconds
# Train iteration 146 completed after  2.492050886154175 seconds
# Train iteration 147 completed after  2.6800031661987305 seconds
# Train iteration 148 completed after  2.929819107055664 seconds
# Train iteration 149 completed after  2.5577011108398438 seconds
# Train iteration 150 completed after  2.4147660732269287 seconds
# Train iteration 151 completed after  2.5024282932281494 seconds
# Train iteration 152 completed after  2.7345962524414062 seconds
# Train iteration 153 completed after  2.656156301498413 seconds
# Train iteration 154 completed after  2.450594186782837 seconds
# Train iteration 155 completed after  2.28121018409729 seconds
# Train iteration 156 completed after  2.270606279373169 seconds
# Train iteration 157 completed after  2.3226089477539062 seconds
# Train iteration 158 completed after  2.3324620723724365 seconds
# Train iteration 159 completed after  2.2653391361236572 seconds
# Train iteration 160 completed after  2.275787115097046 seconds
# Train iteration 161 completed after  2.237460136413574 seconds
# Train iteration 162 completed after  2.2487740516662598 seconds
# Train iteration 163 completed after  2.3232970237731934 seconds
# Train iteration 164 completed after  2.392188787460327 seconds
# Train iteration 165 completed after  2.5681090354919434 seconds
# Train iteration 166 completed after  2.437721014022827 seconds
# Train iteration 167 completed after  2.4388651847839355 seconds
# Train iteration 168 completed after  2.4432120323181152 seconds
# Train iteration 169 completed after  2.376779079437256 seconds
# Train iteration 170 completed after  2.292423963546753 seconds
# Train iteration 171 completed after  2.244591236114502 seconds
# Train iteration 172 completed after  2.2434988021850586 seconds
# Train iteration 173 completed after  2.2614309787750244 seconds
# Train iteration 174 completed after  2.2560951709747314 seconds
# Train iteration 175 completed after  2.2443389892578125 seconds
# Train iteration 176 completed after  2.3594818115234375 seconds
# Train iteration 177 completed after  2.407755136489868 seconds
# Train iteration 178 completed after  2.2278201580047607 seconds
# Train iteration 179 completed after  2.2566282749176025 seconds
# Train iteration 180 completed after  2.2393710613250732 seconds
# Train iteration 181 completed after  2.5790200233459473 seconds
# Train iteration 182 completed after  2.363095998764038 seconds
# Train iteration 183 completed after  2.2787058353424072 seconds
# Train iteration 184 completed after  2.249147891998291 seconds
# Train iteration 185 completed after  2.2459378242492676 seconds
# Train iteration 186 completed after  2.227761745452881 seconds
# Train iteration 187 completed after  2.2467880249023438 seconds
# Train iteration 188 completed after  2.4532389640808105 seconds
# Train iteration 189 completed after  2.4612579345703125 seconds
# Train iteration 190 completed after  2.349763870239258 seconds
# Train iteration 191 completed after  2.4389610290527344 seconds
# Train iteration 192 completed after  2.3794713020324707 seconds
# Train iteration 193 completed after  2.2940032482147217 seconds
# Train iteration 194 completed after  2.250197172164917 seconds
# Train iteration 195 completed after  2.2453932762145996 seconds
# Train iteration 196 completed after  2.243692636489868 seconds
# Train iteration 197 completed after  2.25219988822937 seconds
# Train iteration 198 completed after  2.2346627712249756 seconds
# Train iteration 199 completed after  2.235542058944702 seconds
# Train iteration 200 completed after  2.4701030254364014 seconds
# Train iteration 201 completed after  2.2885539531707764 seconds
# Train iteration 202 completed after  2.2231497764587402 seconds
# Train iteration 203 completed after  2.233229160308838 seconds
# Train iteration 204 completed after  2.2413690090179443 seconds
# Train iteration 205 completed after  2.22668194770813 seconds
# Train iteration 206 completed after  2.2315709590911865 seconds
# Train iteration 207 completed after  2.2569327354431152 seconds
# Train iteration 208 completed after  2.2484381198883057 seconds
# Train iteration 209 completed after  2.2584078311920166 seconds
# Train iteration 210 completed after  2.2483158111572266 seconds
# Train iteration 211 completed after  2.277773141860962 seconds
# Train iteration 212 completed after  2.444301128387451 seconds
# Train iteration 213 completed after  2.3204567432403564 seconds
# Train iteration 214 completed after  2.305922031402588 seconds
# Train iteration 215 completed after  2.3417060375213623 seconds
# Train iteration 216 completed after  2.335515260696411 seconds
# Train iteration 217 completed after  2.253664970397949 seconds
# Train iteration 218 completed after  2.282979965209961 seconds
# Train iteration 219 completed after  2.2362420558929443 seconds
# Train iteration 220 completed after  2.2314629554748535 seconds
# Train iteration 221 completed after  2.2821121215820312 seconds
# Train iteration 222 completed after  2.255769968032837 seconds
# Train iteration 223 completed after  2.366755962371826 seconds
# Train iteration 224 completed after  2.424989938735962 seconds
# Train iteration 225 completed after  2.2369461059570312 seconds
# Train iteration 226 completed after  2.2828269004821777 seconds
# Train iteration 227 completed after  2.2313857078552246 seconds
# Train iteration 228 completed after  2.2386560440063477 seconds
# Train iteration 229 completed after  2.2342820167541504 seconds
# Train iteration 230 completed after  2.2339189052581787 seconds
# Train iteration 231 completed after  2.226975917816162 seconds
# Train iteration 232 completed after  2.2402231693267822 seconds
# Train iteration 233 completed after  2.242581605911255 seconds
# Train iteration 234 completed after  2.2407281398773193 seconds
# Train iteration 235 completed after  2.3887460231781006 seconds
# Train iteration 236 completed after  2.364941120147705 seconds
# Train iteration 237 completed after  2.221304178237915 seconds
# Train iteration 238 completed after  2.2439448833465576 seconds
# Train iteration 239 completed after  2.2338671684265137 seconds
# Train iteration 240 completed after  2.2149713039398193 seconds
# Train iteration 241 completed after  2.2194151878356934 seconds
# Train iteration 242 completed after  2.232495069503784 seconds
# Train iteration 243 completed after  2.241389036178589 seconds
# Train iteration 244 completed after  2.3062641620635986 seconds
# Train iteration 245 completed after  2.3071467876434326 seconds
# Train iteration 246 completed after  2.262427806854248 seconds
# Train iteration 247 completed after  2.462150812149048 seconds
# Train iteration 248 completed after  2.496458053588867 seconds
# Train iteration 249 completed after  2.3088440895080566 seconds
# Train iteration 250 completed after  2.313843011856079 seconds
# Train iteration 251 completed after  2.2686212062835693 seconds
# Train iteration 252 completed after  2.2297098636627197 seconds
# Train iteration 253 completed after  2.202744960784912 seconds
# Train iteration 254 completed after  2.218870162963867 seconds
# Train iteration 255 completed after  2.2457170486450195 seconds
# Train iteration 256 completed after  2.2479848861694336 seconds
# Train iteration 257 completed after  2.2130420207977295 seconds
# Train iteration 258 completed after  2.221914052963257 seconds
# Train iteration 259 completed after  2.4299652576446533 seconds
# Train iteration 260 completed after  2.3167619705200195 seconds
# Train iteration 261 completed after  2.2071468830108643 seconds
# Train iteration 262 completed after  2.2117230892181396 seconds
# Train iteration 263 completed after  2.205845832824707 seconds
# Train iteration 264 completed after  2.211717128753662 seconds
# Train iteration 265 completed after  2.218003988265991 seconds
# Train iteration 266 completed after  2.316689968109131 seconds
# Train iteration 267 completed after  2.220329999923706 seconds
# Train iteration 268 completed after  2.2300360202789307 seconds
# Train iteration 269 completed after  2.2069718837738037 seconds
# Train iteration 270 completed after  2.22688889503479 seconds
# Train iteration 271 completed after  2.7490897178649902 seconds
# Train iteration 272 completed after  2.9851577281951904 seconds
# Train iteration 273 completed after  2.5359721183776855 seconds
# Train iteration 274 completed after  2.6763110160827637 seconds
# Train iteration 275 completed after  2.403998851776123 seconds
# Train iteration 276 completed after  2.3582611083984375 seconds
# Train iteration 277 completed after  2.3038270473480225 seconds
# Train iteration 278 completed after  2.2284939289093018 seconds
# Train iteration 279 completed after  2.377964973449707 seconds
# Train iteration 280 completed after  2.299055814743042 seconds
# Train iteration 281 completed after  2.763068199157715 seconds
# Train iteration 282 completed after  2.75167179107666 seconds
# Train iteration 283 completed after  2.454400062561035 seconds
# Train iteration 284 completed after  2.3981728553771973 seconds
# Train iteration 285 completed after  2.5311789512634277 seconds
# Train iteration 286 completed after  2.553886890411377 seconds
# Train iteration 287 completed after  2.5670619010925293 seconds
# Train iteration 288 completed after  2.2962870597839355 seconds
# Train iteration 289 completed after  2.215564250946045 seconds
# Train iteration 290 completed after  2.2090981006622314 seconds
# Train iteration 291 completed after  2.20639705657959 seconds
# Train iteration 292 completed after  2.1931982040405273 seconds
# Train iteration 293 completed after  2.3675320148468018 seconds
# Train iteration 294 completed after  2.3256030082702637 seconds
# Train iteration 295 completed after  2.183770179748535 seconds
# Train iteration 296 completed after  2.173266887664795 seconds
# Train iteration 297 completed after  2.185244083404541 seconds
# Train iteration 298 completed after  2.168850898742676 seconds
# Train iteration 299 completed after  2.1705448627471924 seconds
# Train iteration 300 completed after  2.1738598346710205 seconds
# Validation iteration 1 completed after  2.1279916763305664 seconds
# Validation iteration 2 completed after  2.0316901206970215 seconds
# Validation iteration 3 completed after  2.0377390384674072 seconds
# Validation iteration 4 completed after  2.0139479637145996 seconds
# Validation iteration 5 completed after  2.025573968887329 seconds
# Validation iteration 6 completed after  2.268306255340576 seconds
# Validation iteration 7 completed after  2.066675901412964 seconds
# Validation iteration 8 completed after  2.0216941833496094 seconds
# Validation iteration 9 completed after  2.0152790546417236 seconds
# Validation iteration 10 completed after  2.024772882461548 seconds
# Validation iteration 11 completed after  2.0091378688812256 seconds
# Validation iteration 12 completed after  2.022091865539551 seconds
# Validation iteration 13 completed after  2.0211901664733887 seconds
# Validation iteration 14 completed after  2.037827968597412 seconds
# Validation iteration 15 completed after  2.060722827911377 seconds
# Validation iteration 16 completed after  2.0376131534576416 seconds
# Validation iteration 17 completed after  2.046560049057007 seconds
# Validation iteration 18 completed after  2.0338568687438965 seconds
# Validation iteration 19 completed after  2.299064874649048 seconds
# Validation iteration 20 completed after  2.1121110916137695 seconds
# Validation iteration 21 completed after  2.0230820178985596 seconds
# Validation iteration 22 completed after  2.018139362335205 seconds
# Validation iteration 23 completed after  2.030747890472412 seconds
# Validation iteration 24 completed after  2.0160348415374756 seconds
# Validation iteration 25 completed after  2.033437967300415 seconds
# Validation iteration 26 completed after  2.0260531902313232 seconds
# Validation iteration 27 completed after  2.024719715118408 seconds
# Validation iteration 28 completed after  2.0325241088867188 seconds
# Validation iteration 29 completed after  2.137838125228882 seconds
# Validation iteration 30 completed after  2.0257649421691895 seconds
# Validation iteration 31 completed after  2.058605909347534 seconds
# Validation iteration 32 completed after  2.2844409942626953 seconds
# Validation iteration 33 completed after  2.104670286178589 seconds
# Validation iteration 34 completed after  2.024451732635498 seconds
# Validation iteration 35 completed after  2.0166687965393066 seconds
# Validation iteration 36 completed after  2.011129140853882 seconds
# Validation iteration 37 completed after  2.029705762863159 seconds
# Validation iteration 38 completed after  2.017826795578003 seconds
# Validation iteration 39 completed after  2.0315959453582764 seconds
# Validation iteration 40 completed after  2.041051149368286 seconds
# Validation iteration 41 completed after  2.0403940677642822 seconds
# Validation iteration 42 completed after  2.028045654296875 seconds
# Validation iteration 43 completed after  2.0498480796813965 seconds
# Validation iteration 44 completed after  2.052809953689575 seconds
# Validation iteration 45 completed after  2.3093628883361816 seconds
# Validation iteration 46 completed after  2.1016130447387695 seconds
# Validation iteration 47 completed after  2.0209250450134277 seconds
# Validation iteration 48 completed after  2.0708367824554443 seconds
# Validation iteration 49 completed after  2.0460140705108643 seconds
# Validation iteration 50 completed after  2.0681519508361816 seconds
# Validation iteration 51 completed after  2.0431301593780518 seconds
# Validation iteration 52 completed after  2.028514862060547 seconds
# Validation iteration 53 completed after  2.024507999420166 seconds
# Validation iteration 54 completed after  2.024001121520996 seconds
# Validation iteration 55 completed after  2.041440963745117 seconds
# Validation iteration 56 completed after  2.043186902999878 seconds
# Validation iteration 57 completed after  2.135352849960327 seconds
# Validation iteration 58 completed after  2.2847328186035156 seconds
# Validation iteration 59 completed after  2.0989291667938232 seconds
# Validation iteration 60 completed after  2.019472122192383 seconds
# Validation iteration 61 completed after  2.031140089035034 seconds
# Validation iteration 62 completed after  2.0170040130615234 seconds
# Validation iteration 63 completed after  2.0347390174865723 seconds
# Validation iteration 64 completed after  2.0272629261016846 seconds
# Validation iteration 65 completed after  2.0289530754089355 seconds
# Validation iteration 66 completed after  2.0218498706817627 seconds
# Validation iteration 67 completed after  2.030348062515259 seconds
# Validation iteration 68 completed after  2.036712884902954 seconds
# Validation iteration 69 completed after  2.0477092266082764 seconds
# Validation iteration 70 completed after  2.03828501701355 seconds
# Validation iteration 71 completed after  2.314274787902832 seconds
# Validation iteration 72 completed after  2.0877997875213623 seconds
# Validation iteration 73 completed after  2.017709970474243 seconds
# Validation iteration 74 completed after  2.0407259464263916 seconds
# Validation iteration 75 completed after  2.0208330154418945 seconds
# Validation iteration 76 completed after  2.030381917953491 seconds
# Validation iteration 77 completed after  2.0242831707000732 seconds
# Validation iteration 78 completed after  2.0331361293792725 seconds
# Validation iteration 79 completed after  2.009488105773926 seconds
# Validation iteration 80 completed after  2.032536029815674 seconds
# Validation iteration 81 completed after  2.0342369079589844 seconds
# Validation iteration 82 completed after  2.03174090385437 seconds
# Validation iteration 83 completed after  2.0877151489257812 seconds
# Validation iteration 84 completed after  2.406608819961548 seconds
# Validation iteration 85 completed after  2.083847761154175 seconds
# Validation iteration 86 completed after  2.0369532108306885 seconds
# Validation iteration 87 completed after  2.016045093536377 seconds
# Validation iteration 88 completed after  2.029021739959717 seconds
# Validation iteration 89 completed after  2.0200388431549072 seconds
# Validation iteration 90 completed after  2.0372278690338135 seconds
# Validation iteration 91 completed after  2.052595853805542 seconds
# Validation iteration 92 completed after  2.0531861782073975 seconds
# Validation iteration 93 completed after  2.0307178497314453 seconds
# Validation iteration 94 completed after  2.051943063735962 seconds
# Validation iteration 95 completed after  2.040847063064575 seconds
# Validation iteration 96 completed after  2.046422004699707 seconds
# Validation iteration 97 completed after  2.284230947494507 seconds
# Validation iteration 98 completed after  2.076275110244751 seconds
# Validation iteration 99 completed after  2.0493690967559814 seconds
# Validation iteration 100 completed after  2.076244831085205 seconds
# Epoch 100 completed after  1027.036467075348 seconds

# %% [markdown]
# <b>Print out the Accuracy and plot the loss stored in the list <code>loss_list</code> for every iteration and take a screen shot.</b>

# %%
accuracy
# Out:
# 0.9935

# %%
plt.plot(loss_list)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# <h2 id="Question_3">Question 3:Find the misclassified samples</h2>

# %% [markdown]
# <b>Identify the first four misclassified samples using the validation data:</b>

# %%
def show_data(data_sample):
    plt.imshow(data_sample[0].numpy().reshape(224, 224, 3), cmap='coolwarm')
    plt.title('y = ' + str(data_sample[1].item()))

# %%
# Plot the misclassified samples

Softmax_fn=nn.Softmax(dim=-1)
count = 0
for x, y in validation_dataset:
    z = model(x.reshape(224, 3, 32, 7))
    yhat = torch.max(z, 1)
    if yhat != y:
        show_data((x, y))
        plt.show()
        #print("yhat:", yhat)
        print("probability of class ", torch.max(Softmax_fn(z)).item())
        count += 1
    if count >= 4:
        break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# probability of class  0.9267064332962036
# probability of class  0.9824334383010864
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# probability of class  0.9606386423110962
# probability of class  0.7665048837661743

# %%
validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=1)

sampleSeq=0
count = 0
for x_test, y_test in validation_loader:
    # set model to eval 
    model.eval()
    #make a prediction 
    z = model(x_test)
    #find max 
    _, yhat = torch.max(z.data, 1)
    if yhat != y_test:
      idx=sampleSeq
      print("sample#: %d - predicted value: %d - actual value: %d" % (idx, yhat, y_test))
      count += 1       
    if count >=4:
      break
    sampleSeq += 1
# Out:
# sample#: 1 - predicted value: 1 - actual value: 0
# sample#: 26 - predicted value: 0 - actual value: 1
# sample#: 79 - predicted value: 1 - actual value: 0
# sample#: 245 - predicted value: 1 - actual value: 0

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/share-notebooks.html?utm_source=Exinfluencer&utm_content=000026UJ&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01&utm_medium=Exinfluencer&utm_term=10006555"> CLICK HERE </a> Click here to see how to share your notebook.

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-21  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>

# %% [markdown]
# Copyright &copy; 2018 <a href="cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01">MIT License</a>.
